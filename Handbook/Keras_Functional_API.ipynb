# %% [markdown]
# ## Functional API Tutorial
#
# #### Day 1
# Preliminary of the model.
# Different approaches

# %%
import numpy as np
import keras
import imdb_functions
from keras.layers import Input, Dense
from keras.models import Model # For functional API
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ##### One other option to use keras is through TF
# import tensorflow as tf
# from tensorflow import keras #import tensorflow.keras as keras
# from tensorflow.keras.layers import Input, Dense
# from tensorflow.keras.models import Model # For functional API
# import numpy as np
# from sklearn.feature_extraction.text import CountVectorizer

# %%
def load_imdb(path, shuffle=True, random_state=42):
    import glob 
    print("Loading the imdb data")
    
    train_neg_files = glob.glob(path+"/train/neg/*.txt")
    train_pos_files = glob.glob(path+"/train/pos/*.txt")
    
    X_train_corpus = []
    y_train = []
    
    for tnf in train_neg_files:
        f = open(tnf, 'r', encoding="utf8")
        line = f.read()
        X_train_corpus.append(line)
        y_train.append(0)
        f.close()
    
    for tpf in train_pos_files:
        f = open(tpf, 'r', encoding="utf8")
        line = f.read()
        X_train_corpus.append(line)
        y_train.append(1)
        f.close()
    
    print("Train Data loaded.")
    
    test_neg_files = glob.glob(path+"/test/neg/*.txt")
    test_pos_files = glob.glob(path+"/test/pos/*.txt")
    
    X_test_corpus = []
    y_test = []
    
    for tnf in test_neg_files:
        f = open(tnf, 'r', encoding="utf8")
        X_test_corpus.append(f.read())
        y_test.append(0)
        f.close()
    
    for tpf in test_pos_files:
        f = open(tpf, 'r', encoding="utf8")
        X_test_corpus.append(f.read())
        y_test.append(1)
        f.close()
    
    print("Test Data loaded.")
    
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    
    if shuffle:
        np.random.seed(random_state)
        indices = np.random.permutation(len(y_train))       
        
        X_train_corpus = [X_train_corpus[i] for i in indices]
        y_train = y_train[indices]
        
        indices = np.random.permutation(len(y_test))
        
        X_test_corpus = [X_test_corpus[i] for i in indices]
        y_test = y_test[indices]
        
    return X_train_corpus, y_train, X_test_corpus , y_test

# %%
path = r"/Users/ekremguzelyel/Desktop/Assignments/Research/aclImdb"
X_train_corpus , y_train, X_test_corpus , y_test = load_imdb(path)
# Out:
# Loading the imdb data
# Train Data loaded.
# Test Data loaded.

# %%
print('len(X_train_corpus)', len(X_train_corpus),
      '\ny_train.shape', y_train.shape,
      '\nlen(X_test_corpus)', len(X_test_corpus),
      '\ny_test.shape', y_test.shape)
# Out:
# len(X_train_corpus) 25000
# y_train.shape (25000,)
# len(X_test_corpus) 25000
# y_test.shape (25000,)

# %% [markdown]
# ### Vectorizer

# %%
token = r"(?u)\b[\w\'/]+\b"
# Use corpus here. Dk y.
#mind
vectorizer = CountVectorizer(token_pattern=token, min_df=5, stop_words=["the","a","of","and","br","to"])
X_train_vector = vectorizer.fit_transform(X_train_corpus)
X_test_vector = vectorizer.transform(X_test_corpus)

# %%
X_train_vector.shape
# Out:
# (25000, 28237)

# %%
input_nodes = Input(shape=(X_train_vector.shape[1],)) # Returns a Tensor

# %%
type(input_nodes)
# Out:
# tensorflow.python.framework.ops.Tensor

# %%
# a layer instance is callable on a tensor, and returns a tensor
x = Dense(30, activation='relu')(input_nodes)
x = Dense(30, activation='relu')(x)
output_nodes = Dense(1, activation='sigmoid')(input_nodes) ## it was (x) before

# %%
# This creates a model that includes
# the Input layer and three Dense layers
model = Model(inputs=input_nodes, outputs=output_nodes)
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(X_train_vector, y_train, epochs=2)  # starts training
# Out:
# Epoch 1/2
# 25000/25000 [==============================] - 6s 238us/step - loss: 0.2040 - acc: 0.9383
# Epoch 2/2
# 25000/25000 [==============================] - 5s 214us/step - loss: 0.1669 - acc: 0.9533

# %%
loss, accuracy = model.evaluate(X_test_vector, y_test)
# Out:
# 25000/25000 [==============================] - 4s 180us/step

# %%
loss, accuracy
# Out:
# (0.2805835545945167, 0.89344)

# %%
score = model.evaluate(X_train_vector, y_train)
# Out:
# 25000/25000 [==============================] - 5s 193us/step

# %%
score
# Out:
# [0.14032445752620698, 0.96548]

# %% [markdown]
# __Question:__ The output of model.predict happened to be a numpy array. Why this wasn't tha case for logistic regression in SkLearn?

# %%
prediction_result= model.predict(X_test_vector, batch_size=None)

# %%
prediction_result[:50]
# Out:
# array([[0.47845063],
#        [0.836907  ],
#        [0.9691989 ],
#        [0.01076878],
#        [0.12572308],
#        [0.15509939],
#        [0.7812954 ],
#        [0.93552536],
#        [0.9683479 ],
#        [0.864189  ],
#        [0.68588114],
#        [0.6666814 ],
#        [0.43990278],
#        [0.28491402],
#        [0.85630757],
#        [0.7985754 ],
#        [0.01198623],
#        [0.02258616],
#        [0.6514368 ],
#        [0.34247124],
#        [0.7071451 ],
#        [0.46450958],
#        [0.03223292],
#        [0.5372605 ],
#        [0.00122444],
#        [0.18969762],
#        [0.9825509 ],
#        [0.22159268],
#        [0.37487566],
#        [0.15257847],
#        [0.03898124],
#        [0.10919598],
#        [0.47213268],
#        [0.861729  ],
#        [0.04137871],
#        [0.08974812],
#        [0.9277585 ],
#        [0.8711819 ],
#        [0.89770776],
#        [0.00331046],
#        [0.99497014],
#        [0.872597  ],
#        [0.07298311],
#        [0.9538998 ],
#        [0.8940372 ],
#        [0.05027941],
#        [0.07586839],
#        [0.79786384],
#        [0.81368256],
#        [0.1314174 ]], dtype=float32)

# %% [markdown]
# --------
# __Task:__ Map prediction results with documents. Print out best n document. (Same as in IMDB_SkLearn)

# %%
len(prediction_result), X_train_vector.shape
# Out:
# (25000, (25000, 28237))

# %%
type(prediction_result)
# Out:
# numpy.ndarray

# %% [markdown]
# Turns out np.column_stack cannot be used, since we want to keep the pair
# relationship between the vector and its prediction results.
# Stacking of them will result adding prediction into vector as the last
# element..

# %%
# This does the job, but find a better way to zip two numpy arrays.
vc_pred_pair = list(zip(X_train_vector.toarray(), prediction_result))

#np.column_stack((X_train_vector.toarray(), prediction_result))

# %%
vc_pred_pair
# Out:
# [(array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.47845063], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.836907], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9691989], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.01076878], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.12572308], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.15509939], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.7812954], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.93552536], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9683479], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.864189], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.68588114], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.6666814], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.43990278], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.28491402], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.85630757], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.7985754], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.01198623], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.02258616], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.6514368], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.34247124], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.7071451], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.46450958], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.03223292], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.5372605], dtype=float32)),
#  (array([1, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.00122444], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.18969762], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9825509], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.22159268], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.37487566], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.15257847], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.03898124], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.10919598], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.47213268], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.861729], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.04137871], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.08974812], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9277585], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8711819], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.89770776], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.00331046], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.99497014], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.872597], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.07298311], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9538998], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8940372], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.05027941], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.07586839], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.79786384], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.81368256], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.1314174], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.44069684], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.11652791], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.99855334], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9994869], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.5011134], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.03823731], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.03607272], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.61841667], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.02354617], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.00335446], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.968123], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.56594867], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8313356], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8309182], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.
dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.32053187], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.02784953], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9167611], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.05490183], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.6965697], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.4539405], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.01524463], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.2701771], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.01150884], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8297068], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.00144828], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.45201713], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.13262594], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8510744], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.47754592], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.28093877], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8344333], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.07017934], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.04333071], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9140219], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.81397164], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.88968116], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.65554], dtype=float32)),
#  (array([1, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8803102], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.6407332], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.01132318], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.3603595], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.75295687], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8805929], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.6229211], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.59909505], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.21974143], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.79044276], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.19762605], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.13317618], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.95614856], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.124874], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.00046187], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.4073497], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8609212], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.4426648], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.990337], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.6618701], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.00831377], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.99965715], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.10366908], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9022166], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.92732275], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.07621677], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.00838867], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.34647945], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.06226713], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.1766081], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.05901894], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.00099776], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9124737], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.03566793], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8605246], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.60406893], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.63032275], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.44834614], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.4012768], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.27383703], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.62626463], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.03912986], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.85987884], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8845076], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8593755], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8241898], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.7037124], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9383644], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.32461908], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.04452541], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.64614594], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.2567176], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.25484136], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.0001968], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.03865544], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.75473255], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.94884914], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.99524635], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.38304535], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.18857008], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.25773576], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.04753523], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.31801745], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.67284906], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8889559], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.00019693], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.19967829], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.23789528], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.6095549], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.08328819], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.18146037], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9958896], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.03399596], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.94134724], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.78957236], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9559151], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.8535386], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.621378], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.84382486], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.12494857], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.93872476], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9569778], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.06615906], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.06233886], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.7244626], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9237495], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.71639186], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.77585745], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.17960893], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.00254718], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.13145393], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.4928113], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.0178427], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.4613461], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.756687], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.1771103], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.0088861], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.03904723], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9177966], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.7082268], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.992823], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.9721388], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.247131], dtype=float32)),
#  (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#   array([0.33370522], dtype=float32)),
#  ...]

# %%
vc_pred_pair_sorted = sorted(vc_pred_pair, key= lambda x:x[1], reverse=True)

# %% [markdown]
# #### All in one

# %%
import keras
import numpy as np
from keras.layers import Input, Dense
from keras.activations import sigmoid,relu
from keras.models import Model
from sklearn.feature_extraction.text import CountVectorizer

# X_train_vector , y_train, X_test_vector , y_test = imdb_functions.load_and_vectorize()
# import load_imdb() to your notebook
path = r"/Users/ekremguzelyel/Desktop/Assignments/Research/aclImdb"
X_train_corpus , y_train, X_test_corpus , y_test = load_imdb(path)

token = r"(?u)\b[\w\'/]+\b"
vectorizer = CountVectorizer(token_pattern=token, min_df=5, stop_words=["the","a","of","and","br","to"])
X_train_vector = vectorizer.fit_transform(X_train_corpus)
X_test_vector = vectorizer.transform(X_test_corpus)

# Create tensor/model background.
input_nodes = Input(shape=(X_train_vector.shape[1],))
x = Dense(64, activation='relu', kernel_initializer='random_uniform')(input_nodes)
# x = Dense(64, activation='relu')(x)
output_nodes = Dense(1, activation='sigmoid')(x) ##  (input_nodes) if there's no hidden layer

# Create the model with layers specified above.
model = Model(inputs=input_nodes, outputs=output_nodes)
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(X_train_vector, y_train, epochs=2)  # starts training

loss, accuracy = model.evaluate(X_test_vector, y_test)
print(loss, accuracy)
prediction_result= model.predict(X_test_vector, batch_size=None)
# Out:
# Loading the imdb data
# Train Data loaded.
# Test Data loaded.
# Epoch 1/2
# 25000/25000 [==============================] - 32s 1ms/step - loss: 0.3274 - acc: 0.8692
# Epoch 2/2
# 25000/25000 [==============================] - 29s 1ms/step - loss: 0.1176 - acc: 0.9588
# 25000/25000 [==============================] - 6s 251us/step
# 0.3504314879465103 0.86964

# %%
loss, accuracy
# Out:
# (0.3504314879465103, 0.86964)
